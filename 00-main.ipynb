# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# 00-testing-0

# %%
# !pip3 install wandb

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import wandb
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler
path = '/content/drive/MyDrive/Colab Notebooks/Projects/Covid19-1'
from sklearn.model_selection import train_test_split

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Projects/Covid19-1'

# %%
import os
os.listdir('/content/drive/MyDrive/Colab Notebooks/Projects/Covid19-1/')
# Out:
# ['00-testing-0.ipynb', 'archive.zip', 'covid19_world.csv', 'cleaned_data.csv']

# %%
data = pd.read_csv(f'{path}/covid19_world.csv')

# %%
data[:2]
# Out:
#   ObservationDate Country_Region Province_State  ...  Deaths  Recovered  Active
# 0      2020-01-22          China          Anhui  ...     0.0        0.0     0.0
# 1      2020-01-22          China        Beijing  ...     0.0        0.0     0.0
#
# [2 rows x 7 columns]

# %%
data.dropna(inplace=True)

# %%
data.drop(['Province_State'],axis=1,inplace=True)

# %%
import re
ObservationDate = []
for od in data['ObservationDate']:
  ObservationDate.append(re.sub('-','',str(od)))
data['ObservationDate'] = ObservationDate

# %%
data.to_csv(f'{path}/cleaned_data.csv',index=False)

# %%
data = pd.read_csv(f'{path}/cleaned_data.csv')

# %%
data.head()
# Out:
#    ObservationDate Country_Region  Confirmed  Deaths  Recovered  Active
# 0         20200122          China          1     0.0        0.0     0.0
# 1         20200122          China         14     0.0        0.0     0.0
# 2         20200122          China          6     0.0        0.0     0.0
# 3         20200122          China          1     0.0        0.0     0.0
# 4         20200122          China          0     0.0        0.0     0.0

# %%
from sklearn.model_selection import train_test_split

# %%
tf.random.set_seed(42)
bgi_data,data = train_test_split(data,test_size=0.01)

# %%
len(data),len(bgi_data)
# Out:
# (10065, 996379)

# %%
ct = make_column_transformer(
    (MinMaxScaler(),['ObservationDate']),
    (OneHotEncoder(),['Country_Region'])
)
X = data.drop(['Confirmed','Deaths','Recovered','Active'],axis=1)
y = data.drop(['ObservationDate','Country_Region'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
ct.fit(X_train)
X_train = ct.transform(X_train)
X_test = ct.transform(X_test)

# %%
from wandb.keras import WandbCallback

# %%
# wandb.init(project='Covid19-1-test0',name='test-1')
# model = tf.keras.Sequential([
#   tf.keras.layers.Dense(1)
# ])
# model.compile(loss=tf.keras.losses.mae,metrics=['mae','mse'],optimizer=tf.keras.optimizers.Adam())
# model.fit(X_train,tf.constant(y_train),validation_data=(X_test,tf.constant(y_test)),epochs=100,callbacks=[WandbCallback()])

# %%
# Layers = 
# Epochs = 
# learning rate = 
# total neurons = 
# activation type =

# %%
# model = tf.keras.Sequential([
#   tf.keras.layers.Dense(1)
# ])
# model.compile(loss=tf.keras.losses.mae,metrics=['mae','mse'],optimizer=tf.keras.optimizers.Adam())
# # model.fit(X_train,tf.constant(y_train),validation_data=(X_test,tf.constant(y_test)),epochs=100,callbacks=[WandbCallback()])
# model.fit(X_train,tf.constant(y_train),validation_data=(X_test,tf.constant(y_test)),epochs=100)

# %%
def runtime_prob():
  for _ in range(10000000):
    print(_)
  return 'Done'

# %%
class Experimentation:
  def experiment(self,amount_of_layers:int,epochs:int,lr:int,optimizer_,neurons_per_layer:int,activation_types:list,metrics_:list,name:str,project_name:str):
    print('OK')
    wandb.init(project=project_name,name=name)
    print('OK')
    model = tf.keras.Sequential()
    print('OK')
    if int(amount_of_layers) != len(activation_types):
      return 'Amout of Layers and Activation_types'
    print('OK')
    for activation_type in activation_types:
      model.add(tf.keras.layers.Dense(neurons_per_layer,activation=activation_type))
    model.add(tf.keras.layers.Dense(1))
    print('OK')
    # print(model.summary())
    model.compile(loss=tf.keras.losses.mae,metrics=metrics_,optimizer=optimizer_(lr=lr)) # change
    print('OK')
    model.fit(X_train,tf.constant(y_train),validation_data=(X_test,tf.constant(y_test)),epochs=epochs,callbacks=[WandbCallback()]) # callbacks # change
    print('OK')
    return True

# %%
E = Experimentation()
# E.experiment(amount_of_layers=6,epochs=50,lr=0.001,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=1,activation_types=[None,None,None,None,None,None],metrics_=['mae'],name='g',project_name='g')

# %%
E.experiment(
  amount_of_layers=1,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=1',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:1wwluaeu) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1657<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055343-1wwluaeu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055343-1wwluaeu/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">tn-Testing-1-tn=1000</strong>: <a href="https://wandb.ai/ranuga-d/Covid19-0-Project-Testing/runs/1wwluaeu" target="_blank">https://wandb.ai/ranuga-d/Covid19-0-Project-Testing/runs/1wwluaeu</a><br/>
# ...Successfully finished last run (ID:1wwluaeu). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.22<br/>
# ...

# %%
E.experiment(
  amount_of_layers=2,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=2',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:2cucy1bg) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1714<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055453-2cucy1bg/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055453-2cucy1bg/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=3,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=3',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:3pzr2j3y) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1937<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055538-3pzr2j3y/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055538-3pzr2j3y/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=4,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=4',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:17dcvbbr) before initializing another...
# <br/>Waiting for W&B process to finish, PID 2171<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055621-17dcvbbr/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055621-17dcvbbr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=5,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=5',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:1pq4ta4x) before initializing another...
# <br/>Waiting for W&B process to finish, PID 2399<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055707-1pq4ta4x/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055707-1pq4ta4x/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=6,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=6',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:yv6ih7ql) before initializing another...
# <br/>Waiting for W&B process to finish, PID 2638<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055753-yv6ih7ql/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055753-yv6ih7ql/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=7,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=7',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:287tdcpl) before initializing another...
# <br/>Waiting for W&B process to finish, PID 2865<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055845-287tdcpl/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055845-287tdcpl/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=8,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=8',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:2szpgpuj) before initializing another...
# <br/>Waiting for W&B process to finish, PID 3101<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_055933-2szpgpuj/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_055933-2szpgpuj/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=9,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=9',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:zqvl7wi3) before initializing another...
# <br/>Waiting for W&B process to finish, PID 3327<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_060023-zqvl7wi3/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_060023-zqvl7wi3/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(
  amount_of_layers=10,
  epochs=75,
  lr=0.001,
  optimizer_=tf.keras.optimizers.Adam,
  neurons_per_layer=1,
  activation_types=[None,None,None,None,None,None,None,None,None,None],
  metrics_=['mae','mse'],
  name='Layer-Testing-1-Layers=10',
  project_name='Covid19-0-Project-Testing'
)
# Out:
# OK
# Finishing last run (ID:2nqq32my) before initializing another...
# <br/>Waiting for W&B process to finish, PID 3560<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_060113-2nqq32my/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_060113-2nqq32my/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
# Epochs

# %%
epochs_types_to_try = [25,125,250] 
for epoch_type_to_try in epochs_types_to_try:
  E.experiment(
    amount_of_layers=1,
    epochs=epoch_type_to_try,
    lr=0.001,
    optimizer_=tf.keras.optimizers.Adam,
    neurons_per_layer=1,
    activation_types=[None],
    metrics_=['mae','mse'],
    name=f'Epochs-Testing-1-Epochs={epoch_type_to_try}',
    project_name='Covid19-0-Project-Testing'
  )
# Out:
# OK
# Finishing last run (ID:2p6jxuhu) before initializing another...
# <br/>Waiting for W&B process to finish, PID 3783<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_060204-2p6jxuhu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_060204-2p6jxuhu/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
# lr

# %%
lr_types_to_try = [1.0,0.1,0.01,0.001,0.0001]
for lr_types_to_try in lr_types_to_try:
  E.experiment(
    amount_of_layers=1,
    epochs=75,
    lr=lr_types_to_try,
    optimizer_=tf.keras.optimizers.Adam,
    neurons_per_layer=1,
    activation_types=[None],
    metrics_=['mae','mse'],
    name=f'lr-Testing-1-lr={lr_types_to_try}',
    project_name='Covid19-0-Project-Testing'
  )
# Out:
# OK
# Finishing last run (ID:11818gah) before initializing another...
# <br/>Waiting for W&B process to finish, PID 4467<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_060425-11818gah/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_060425-11818gah/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
# total nerouns

# %%
E = Experimentation()
total_neurons_to_try = [1000,2500,25000]
for total_neuron_to_try in total_neurons_to_try:
  print(total_neuron_to_try)
  E.experiment(
    amount_of_layers=1,
    epochs=75,
    lr=0.001,
    optimizer_=tf.keras.optimizers.Adam,
    neurons_per_layer=int(total_neuron_to_try),
    activation_types=[None],
    metrics_=['mae','mse'],
    name=f'tn-Testing-1-tn={total_neuron_to_try}',
    project_name='Covid19-0-Project-Testing'
  )
# Out:
# 1000
# OK
# Finishing last run (ID:6qqjzjlz) before initializing another...
# <br/>Waiting for W&B process to finish, PID 6012<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_060933-6qqjzjlz/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_060933-6qqjzjlz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
# activation type

# %%
activation_types = ['linear','swish','relu','tanh']
for activation_type in activation_types:
  E.experiment(
    amount_of_layers=1,
    epochs=75,
    lr=0.001,
    optimizer_=tf.keras.optimizers.Adam,
    neurons_per_layer=total_neuron_to_try,
    activation_types=[activation_type],
    metrics_=['mae','mse'],
    name=f'at-Testing-1-at={activation_type}',
    project_name='Covid19-0-Project-Testing'
  )
# Out:
# OK
# Finishing last run (ID:1j2wv8ao) before initializing another...
# <br/>Waiting for W&B process to finish, PID 7191<br/>Program ended successfully.
# wandb: ERROR Control-C detected -- Run data was not synced
# ...Successfully finished last run (ID:1j2wv8ao). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.22<br/>
#                 Syncing run <strong style="color:#cdcd00">at-Testing-1-at=linear</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ranuga-d/Covid19-0-Project-Testing" target="_blank">https://wandb.ai/ranuga-d/Covid19-0-Project-Testing</a><br/>
#                 Run page: <a href="https://wandb.ai/ranuga-d/Covid19-0-Project-Testing/runs/fbe98ciq" target="_blank">https://wandb.ai/ranuga-d/Covid19-0-Project-Testing/runs/fbe98ciq</a><br/>
# ...

# %% [markdown]
# # Layers = 10
# # Epochs = 750
# # learning rate = 0.1 / 1.0
# # total neurons = 25000
# # activation type = relu | swish / linear (Sigmoid linear softmax Swish ReLU Tanh)

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
import pandas as pd
import tensorflow as tf
import numpy as np
import wandb
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler
path = '/content/drive/MyDrive/Colab Notebooks/Projects/Covid19-1'
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(f'{path}/cleaned_data.csv')

# %%
big_data,data = train_test_split(data,test_size=0.12)

# %%
len(data)
# Out:
# 120774

# %%
len(big_data)
# Out:
# 885670

# %%
ct = make_column_transformer(
    (MinMaxScaler(),['ObservationDate']),
    (OneHotEncoder(),['Country_Region'])
)
X = data.drop(['Confirmed','Deaths','Recovered','Active'],axis=1)
y = data.drop(['ObservationDate','Country_Region'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
ct.fit(X)
X_train = ct.transform(X_train)
X_test = ct.transform(X_test)

# %%
class Experimentation:
  def experiment(self,amount_of_layers:int,epochs:int,lr:int,optimizer_,neurons_per_layer:int,activation_types:list,metrics_:list,name:str,project_name:str):
    if int(amount_of_layers) != len(activation_types):
      print('OK')
      print('OK')
      for i in range(amount_of_layers + 1):
        print(activation_types)
        activation_types.append(activation_types[0])
      print('OK')
    print('OK')
    print('OK')
    wandb.init(project=project_name,name=name)
    print('OK')
    model = tf.keras.Sequential()
    print('OK')
    for activation_type in activation_types:
      model.add(tf.keras.layers.Dense(neurons_per_layer,activation=activation_type))
    model.add(tf.keras.layers.Dense(1))
    print('OK')
    # print(model.summary())
    model.compile(loss=tf.keras.losses.mae,metrics=metrics_,optimizer=optimizer_(lr=lr)) # change
    print('OK')
    model.fit(X_train,tf.constant(y_train),validation_data=(X_test,tf.constant(y_test)),epochs=epochs,callbacks=[WandbCallback()]) # callbacks # change
    print('OK')
    return True

# %%
# Layers = 10
# Epochs = 750
# learning rate = 0.1 / 1.0
# total neurons = 25000
# activation type = relu | swish / linear (Sigmoid linear softmax Swish ReLU Tanh)

# %%
from wandb.keras import WandbCallback

# %%
#[10,750,0.1,25000,'swish'],[10,750,1.0,25000,'swish'],[10,750,0.1,25000,'linear'],[10,750,1.0,25000,'linear']}
E = Experimentation()
E.experiment(amount_of_layers=1,epochs=25,lr=0.1,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['relu'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test1')

# %%
E.experiment(amount_of_layers=1,epochs=25,lr=1.0,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['relu'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test2')

# %%
E.experiment(amount_of_layers=1,epochs=25,lr=0.1,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['swish'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test1')
# Out:
# OK
# OK
# Finishing last run (ID:2qnrj4bj) before initializing another...
# <br/>Waiting for W&B process to finish, PID 9910<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_074753-2qnrj4bj/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_074753-2qnrj4bj/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(amount_of_layers=1,epochs=25,lr=1.0,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['swish'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test1')
# Out:
# OK
# OK
# Finishing last run (ID:1xqttyhx) before initializing another...
# <br/>Waiting for W&B process to finish, PID 10183<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_080128-1xqttyhx/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_080128-1xqttyhx/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(amount_of_layers=1,epochs=25,lr=0.1,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['linear'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test1')
# Out:
# OK
# OK
# Finishing last run (ID:f6tz4iqt) before initializing another...
# <br/>Waiting for W&B process to finish, PID 10544<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_082121-f6tz4iqt/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_082121-f6tz4iqt/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
E.experiment(amount_of_layers=1,epochs=25,lr=1.0,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['linear'],metrics_=['mae','mse'],project_name='Covid19-1-Project-Testing',name='test1')
# Out:
# OK
# OK
# Finishing last run (ID:5miwvgfh) before initializing another...
# <br/>Waiting for W&B process to finish, PID 10910<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_084148-5miwvgfh/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_084148-5miwvgfh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %% [markdown]
# ### Layers = 1
# ### Epochs = 750
# ### learning rate = 0.1
# ### total neurons = 25000
# ### activation type = swish

# %%
y_train = tf.constant(y_train)
y_test = tf.constant(y_test)

# %%
wandb.init(project='Covid19-2-Big-Dog-Model',name='Big-Dog-Model-1')
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(250000,activation='swish'),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(lr=0.1),metrics=['mae','mse'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=5,callbacks=[WandbCallback(log_weights=True),tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Finishing last run (ID:43ispfoh) before initializing another...
# <br/>Waiting for W&B process to finish, PID 11439<br/>Program ended successfully.
# wandb: ERROR Control-C detected -- Run data was not synced
# ...Successfully finished last run (ID:43ispfoh). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.22<br/>
#                 Syncing run <strong style="color:#cdcd00">Big-Dog-Model-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ranuga-d/Covid19-2-Big-Dog-Model" target="_blank">https://wandb.ai/ranuga-d/Covid19-2-Big-Dog-Model</a><br/>
#                 Run page: <a href="https://wandb.ai/ranuga-d/Covid19-2-Big-Dog-Model/runs/b885uwbu" target="_blank">https://wandb.ai/ranuga-d/Covid19-2-Big-Dog-Model/runs/b885uwbu</a><br/>
# ...

# %%
wandb.init(project='Covid19-2-Big-Dog-Model',name='Big-Dog-Model-1')
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(250000,activation='swish'),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(lr=0.1),metrics=['mae','mse'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=5,callbacks=[WandbCallback(log_weights=True),tf.keras.callbacks.EarlyStopping(patience=5),tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mae',factor=0.2,patience=2,min_lr=0.001,verbose=2)])
# Out:
# Finishing last run (ID:b885uwbu) before initializing another...
# <br/>Waiting for W&B process to finish, PID 11482<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_090803-b885uwbu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_090803-b885uwbu/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
wandb.init(project='Covid19-2-Big-Dog-Model',name='Big-Dog-Model-1')
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(25000,activation='swish'),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(lr=0.1),metrics=['mae','mse'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=5,callbacks=[WandbCallback(log_weights=True),tf.keras.callbacks.EarlyStopping(patience=5),tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mae',factor=0.2,patience=2,min_lr=0.001,verbose=2)])
# Out:
# Finishing last run (ID:2g1fa4v6) before initializing another...
# <br/>Waiting for W&B process to finish, PID 11893<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_093453-2g1fa4v6/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_093453-2g1fa4v6/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
wandb.init(project='Covid19-2-Big-Dog-Model',name='Big-Dog-Model-1')
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(25000,activation='swish'),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(lr=0.1),metrics=['mae','mse'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=5,callbacks=[WandbCallback(log_weights=True),tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Finishing last run (ID:3rkvfsyh) before initializing another...
# <br/>Waiting for W&B process to finish, PID 12295<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_100112-3rkvfsyh/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_100112-3rkvfsyh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...

# %%
### Layers = 10
### Epochs = 750
### learning rate = 0.1
### total neurons = 25000
### activation type = swish

# %%
E = Experimentation()
E.experiment(amount_of_layers=1,epochs=5,lr=0.1,optimizer_=tf.keras.optimizers.Adam,neurons_per_layer=25000,activation_types=['swish'],metrics_=['mae','mse'],project_name='Covid19-3-Big-Dog-Model-Testing',name='testing1')
# Out:
# OK
# OK
# Finishing last run (ID:m3ubbcj0) before initializing another...
# <br/>Waiting for W&B process to finish, PID 12387<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>/content/wandb/run-20210315_100427-m3ubbcj0/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210315_100427-m3ubbcj0/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...
